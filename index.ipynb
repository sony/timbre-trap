# %% [markdown]
# # Timbre-Trap
# This demo page is for the paper **Timbre-Trap: A Low-Resource Framework for Instrument-Agnostic Music Transcription**
#
# Source code: https://github.com/sony/timbre-trap

# %% [markdown]
# ## Table of contents
# 1. [Audio Samples](#Audio-Samples)
# 1. [Visualization](#Vigualization)

# %%
from IPython.display import HTML
table ="""
<style>
.myaudio {
    controlslist: noplaybackrate;
    width: 200px;
    controls
}

* {
  box-sizing: border-box;
}

.row {
  display: flex;
  margin-left:-5px;
  margin-right:-5px;
}

.column {
  flex: 50%;
  padding: 5px;
}

table {
  border-collapse: collapse;
  border-spacing: 0;
  width: 100%;
  border: 1px solid #ddd;
}

th, td {
  text-align: left;
  padding: 16px;
}

tr:nth-child(even) {
  background-color: #f2f2f2;
}
</style>
"""
HTML(table)

# %% [markdown]
# ## Audio Samples
# ### Timbre-Trap
# Timbre-Trap reconstructs the CQT coefficents when the latent space switch is in "on" state (Reconstruction).
# It removes timbre from the audio clips when the latent space switch is in "off" state (Sonification).
#
# <table border="0">
#
#
#  <tr>
#     <td style="text-align: left"><b style="font-size:14px">File Name</b></td>
#     <td style="text-align: center; font-size:150%">Mixture</td>
#     <td style="text-align: center; font-size:150%">Bassoon</td>
#     <td style="text-align: center; font-size:150%">Clarinet</td>
#     <td style="text-align: center; font-size:150%">Saxophone</td>
#     <td style="text-align: center; font-size:150%">Violin</td>
#  </tr>
#
#  <tr>
#     <td style="text-align: left"><b style="font-size:14px">Original Audio</b></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr_ref.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr-bassoon_ref.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr-clarinet_ref.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr-saxphone_ref.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr-violin_ref.mp3" controls>alternative text</audio><br/></td>
#  </tr>
#
#  <tr>
#     <td style="text-align: left"><b style="font-size:14px">Reconstruction</b></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr_rec.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr-bassoon_rec.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr-clarinet_rec.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr-saxphone_rec.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr-violin_rec.mp3" controls>alternative text</audio><br/></td>
#  </tr>
#
#  <tr>
#     <td style="text-align: left"><b style="font-size:14px">Sonification<br>Transcription</b></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr_scr.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr-bassoon_scr.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr-clarinet_scr.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr-saxphone_scr.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio/01-AchGottundHerr-violin_scr.mp3" controls>alternative text</audio><br/></td>
#  </tr>
#
# </table>

# %% [markdown]
# ### Timbre-Trap with Skip-Connections
#
# With skip-connections, Timbre-Trap reconstructs CQT coefficents very close to the original audio, resulting in a very high SDR.
#
# But the sonification retains more timbre information than the Timbre-Trap without skip-connections, resulting in a slower F1-score.
#
# <table border="0">
#
#
#  <tr>
#     <td style="text-align: left"><b style="font-size:14px">File Name</b></td>
#     <td style="text-align: center; font-size:150%">Mixture</td>
#     <td style="text-align: center; font-size:150%">Bassoon</td>
#     <td style="text-align: center; font-size:150%">Clarinet</td>
#     <td style="text-align: center; font-size:150%">Saxophone</td>
#     <td style="text-align: center; font-size:150%">Violin</td>
#  </tr>
#
#  <tr>
#     <td style="text-align: left"><b style="font-size:14px">Original Audio</b></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr_ref.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr-bassoon_ref.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr-clarinet_ref.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr-saxphone_ref.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr-violin_ref.mp3" controls>alternative text</audio><br/></td>
#  </tr>
#
#  <tr>
#     <td style="text-align: left"><b style="font-size:14px">Reconstruction</b></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr_rec.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr-bassoon_rec.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr-clarinet_rec.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr-saxphone_rec.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr-violin_rec.mp3" controls>alternative text</audio><br/></td>
#  </tr>
#
#  <tr>
#     <td style="text-align: left"><b style="font-size:14px">Sonification<br>Transcription</b></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr_scr.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr-bassoon_scr.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr-clarinet_scr.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr-saxphone_scr.mp3" controls>alternative text</audio><br/></td>
#     <td style="text-align: center"><audio class="myaudio" src="audio2/01-AchGottundHerr-violin_scr.mp3" controls>alternative text</audio><br/></td>
#  </tr>
#
# </table>

# %% [markdown]
# ## Visualization
# The reconstruction and transcription produced by Timbre-Trap with and without skip-connections
#
# ### URMP test set
# <table>
#    <tr>
#        <td style="text-align: center"><b style="font-size:150%">Timbre-Trap</b></td>
#        <td style="text-align: center"><b style="font-size:150%">Timbre-Trap with Skip-Connections</b></td>
#    </tr>
#    <tr>
#       <td style="text-align: left">
#          <table border="0">
#             <tr>
#                <td style="text-align: left"><b style="font-size:14px"></b></td>
#                <td style="text-align: center; font-size:100%">Ground Truth</td>
#                <td style="text-align: center; font-size:100%">Prediction</td>
#             </tr>
#             <tr>
#                <td style="text-align: left"><b style="font-size:14px">Reconstruction</b></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/urmp_ori.png" alt="sample0"></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/urmp_rec.png" alt="sample0"></td>
#             </tr>
#             <tr>
#                <td style="text-align: left"><b style="font-size:14px">Transcription</b></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/urmp_truth.png" alt="sample0"></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/urmp_mpe.png" alt="sample1"></td>
#             </tr>
#          </table>
#       </td>
#       <td style="text-align: center">
#          <table>
#          <tr>
#             <td style="text-align: center; font-size:100%">Ground Truth</td>
#             <td style="text-align: center; font-size:100%">Prediction</td>
#          </tr>
#          <tr>
#             <td style="text-align: center"><img class="image" width="300" src="img/urmp_ori.png" alt="sample0"></td>
#             <td style="text-align: center"><img class="image" width="300" src="img2/urmp_rec.png" alt="sample0"></td>
#          </tr>
#          <tr>
#             <td style="text-align: center"><img class="image" width="300" src="img/urmp_truth.png" alt="sample0"></td>
#             <td style="text-align: center"><img class="image" width="300" src="img2/urmp_mpe.png" alt="sample1"></td>
#          </tr>
#          </table>
#       </td>
#    </tr>
# </table>

# %% [markdown]
# ### Bach10
# <table>
#    <tr>
#        <td style="text-align: center"><b style="font-size:150%">Timbre-Trap</b></td>
#        <td style="text-align: center"><b style="font-size:150%">Timbre-Trap with Skip-Connections</b></td>
#    </tr>
#    <tr>
#       <td style="text-align: left">
#          <table border="0">
#             <tr>
#                <td style="text-align: left"><b style="font-size:14px"></b></td>
#                <td style="text-align: center; font-size:100%">Ground Truth</td>
#                <td style="text-align: center; font-size:100%">Prediction</td>
#             </tr>
#             <tr>
#                <td style="text-align: left"><b style="font-size:14px">Reconstruction</b></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/bach10_ori.png" alt="sample0"></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/bach10_rec.png" alt="sample0"></td>
#             </tr>
#             <tr>
#                <td style="text-align: left"><b style="font-size:14px">Transcription</b></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/bach10_truth.png" alt="sample0"></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/bach10_mpe.png" alt="sample1"></td>
#             </tr>
#          </table>
#       </td>
#       <td style="text-align: center">
#          <table>
#          <tr>
#             <td style="text-align: center; font-size:100%">Ground Truth</td>
#             <td style="text-align: center; font-size:100%">Prediction</td>
#          </tr>
#          <tr>
#             <td style="text-align: center"><img class="image" width="300" src="img/bach10_ori.png" alt="sample0"></td>
#             <td style="text-align: center"><img class="image" width="300" src="img2/bach10_rec.png" alt="sample0"></td>
#          </tr>
#          <tr>
#             <td style="text-align: center"><img class="image" width="300" src="img/bach10_truth.png" alt="sample0"></td>
#             <td style="text-align: center"><img class="image" width="300" src="img2/bach10_mpe.png" alt="sample1"></td>
#          </tr>
#          </table>
#       </td>
#    </tr>
# </table>

# %% [markdown]
# ### Su
# <table>
#    <tr>
#        <td style="text-align: center"><b style="font-size:150%">Timbre-Trap</b></td>
#        <td style="text-align: center"><b style="font-size:150%">Timbre-Trap with Skip-Connections</b></td>
#    </tr>
#    <tr>
#       <td style="text-align: left">
#          <table border="0">
#             <tr>
#                <td style="text-align: left"><b style="font-size:14px"></b></td>
#                <td style="text-align: center; font-size:100%">Ground Truth</td>
#                <td style="text-align: center; font-size:100%">Prediction</td>
#             </tr>
#             <tr>
#                <td style="text-align: left"><b style="font-size:14px">Reconstruction</b></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/su_ori.png" alt="sample0"></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/su_rec.png" alt="sample0"></td>
#             </tr>
#             <tr>
#                <td style="text-align: left"><b style="font-size:14px">Transcription</b></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/su_truth.png" alt="sample0"></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/su_mpe.png" alt="sample1"></td>
#             </tr>
#          </table>
#       </td>
#       <td style="text-align: center">
#          <table>
#          <tr>
#             <td style="text-align: center; font-size:100%">Ground Truth</td>
#             <td style="text-align: center; font-size:100%">Prediction</td>
#          </tr>
#          <tr>
#             <td style="text-align: center"><img class="image" width="300" src="img/su_ori.png" alt="sample0"></td>
#             <td style="text-align: center"><img class="image" width="300" src="img2/su_rec.png" alt="sample0"></td>
#          </tr>
#          <tr>
#             <td style="text-align: center"><img class="image" width="300" src="img/su_truth.png" alt="sample0"></td>
#             <td style="text-align: center"><img class="image" width="300" src="img2/su_mpe.png" alt="sample1"></td>
#          </tr>
#          </table>
#       </td>
#    </tr>
# </table>

# %% [markdown]
# ### Guitar Set
# <table>
#    <tr>
#        <td style="text-align: center"><b style="font-size:150%">Timbre-Trap</b></td>
#        <td style="text-align: center"><b style="font-size:150%">Timbre-Trap with Skip-Connections</b></td>
#    </tr>
#    <tr>
#       <td style="text-align: left">
#          <table border="0">
#             <tr>
#                <td style="text-align: left"><b style="font-size:14px"></b></td>
#                <td style="text-align: center; font-size:100%">Ground Truth</td>
#                <td style="text-align: center; font-size:100%">Prediction</td>
#             </tr>
#             <tr>
#                <td style="text-align: left"><b style="font-size:14px">Reconstruction</b></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/gu_ori.png" alt="sample0"></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/gu_rec.png" alt="sample0"></td>
#             </tr>
#             <tr>
#                <td style="text-align: left"><b style="font-size:14px">Transcription</b></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/gu_truth.png" alt="sample0"></td>
#                <td style="text-align: center"><img class="image" width="300" src="img/gu_mpe.png" alt="sample1"></td>
#             </tr>
#          </table>
#       </td>
#       <td style="text-align: center">
#          <table>
#          <tr>
#             <td style="text-align: center; font-size:100%">Ground Truth</td>
#             <td style="text-align: center; font-size:100%">Prediction</td>
#          </tr>
#          <tr>
#             <td style="text-align: center"><img class="image" width="300" src="img/gu_ori.png" alt="sample0"></td>
#             <td style="text-align: center"><img class="image" width="300" src="img2/gu_rec.png" alt="sample0"></td>
#          </tr>
#          <tr>
#             <td style="text-align: center"><img class="image" width="300" src="img/gu_truth.png" alt="sample0"></td>
#             <td style="text-align: center"><img class="image" width="300" src="img2/gu_mpe.png" alt="sample1"></td>
#          </tr>
#          </table>
#       </td>
#    </tr>
# </table>
